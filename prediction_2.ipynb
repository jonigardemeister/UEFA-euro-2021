# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn
from scipy.stats import poisson,skellam

# %%
df = pd.read_csv('final_game_results.csv', decimal=',', encoding='utf-8')
df.shape
# Out:
# (625, 6)

# %%
df
# Out:
#             Date Score    Home_team    Away_team  Home_goals  Away_goals
# 0    08 Sep 2018   6-0  Switzerland      Iceland           6           0
# 1    11 Sep 2018   1-0      England  Switzerland           1           0
# 2    12 Oct 2018   2-1      Belgium  Switzerland           2           1
# 3    15 Oct 2018   1-2      Iceland  Switzerland           1           2
# 4    14 Nov 2018   0-1  Switzerland        Qatar           0           1
# ..           ...   ...          ...          ...         ...         ...
# 620  12 Nov 2020   2-1      Hungary      Iceland           2           1
# 621  15 Nov 2020   1-1      Hungary       Serbia           1           1
# 622  18 Nov 2020   2-0      Hungary       Turkey           2           0
# 623  28 Mar 2021   0-3   San Marino      Hungary           0           3
# 624  31 Mar 2021   1-4      Andorra      Hungary           1           4
#
# [625 rows x 6 columns]

# %%
df_rank = pd.read_csv('fifa_rankings_all.csv', decimal=',', encoding='utf-8')
df_rank.shape
# Out:
# (5260, 4)

# %%
df_rank
# Out:
#               date  rank                      team  points
# 0     01 July 2018     1                   Germany    2172
# 1     01 July 2018     2                    France    2164
# 2     01 July 2018     3                  Portugal    2163
# 3     01 July 2018     4                    Brazil    2160
# 4     01 July 2018     5                   Belgium    2124
# ...            ...   ...                       ...     ...
# 5255   27 May 2021   206  Turks and Caicos Islands  843.65
# 5256   27 May 2021   207         US Virgin Islands  829.13
# 5257   27 May 2021   208    British Virgin Islands  826.27
# 5258   27 May 2021   209                  Anguilla  805.42
# 5259   27 May 2021   210                San Marino  804.71
#
# [5260 rows x 4 columns]

# %%
df_rank['date'] = pd.to_datetime(df_rank['date'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df_rank
# Out:
#            date  rank                      team  points
# 0    2018-07-01     1                   Germany    2172
# 1    2018-07-01     2                    France    2164
# 2    2018-07-01     3                  Portugal    2163
# 3    2018-07-01     4                    Brazil    2160
# 4    2018-07-01     5                   Belgium    2124
# ...         ...   ...                       ...     ...
# 5255 2021-05-27   206  Turks and Caicos Islands  843.65
# 5256 2021-05-27   207         US Virgin Islands  829.13
# 5257 2021-05-27   208    British Virgin Islands  826.27
# 5258 2021-05-27   209                  Anguilla  805.42
# 5259 2021-05-27   210                San Marino  804.71
#
# [5260 rows x 4 columns]

# %%
df
# Out:
#           Date Score    Home_team    Away_team  Home_goals  Away_goals
# 0   2018-09-08   6-0  Switzerland      Iceland           6           0
# 1   2018-09-11   1-0      England  Switzerland           1           0
# 2   2018-10-12   2-1      Belgium  Switzerland           2           1
# 3   2018-10-15   1-2      Iceland  Switzerland           1           2
# 4   2018-11-14   0-1  Switzerland        Qatar           0           1
# ..         ...   ...          ...          ...         ...         ...
# 620 2020-11-12   2-1      Hungary      Iceland           2           1
# 621 2020-11-15   1-1      Hungary       Serbia           1           1
# 622 2020-11-18   2-0      Hungary       Turkey           2           0
# 623 2021-03-28   0-3   San Marino      Hungary           0           3
# 624 2021-03-31   1-4      Andorra      Hungary           1           4
#
# [625 rows x 6 columns]

# %%
df['Home_rank'] = -1
df['Away_rank'] = -1

# %%
for index, row in df.iterrows():
    home_team_rank_rows = df_rank[df_rank['team'] == row['Home_team']]
    dates = home_team_rank_rows['date'].values
    home_team_rank_rows = home_team_rank_rows.sort_values(by='date',ascending=True)
    
    previous = False
    previous_rank_row = None
    for index_rank, row_rank in home_team_rank_rows.iterrows():
        date = row_rank['date']
        if date >= row['Date'] and previous:
            df.at[index, 'Home_rank'] = previous_rank_row['rank']
            break;
        elif date < row['Date']: 
            previous = True
            previous_rank_row = row_rank

# %%
for index, row in df.iterrows():
    away_team_rank_rows = df_rank[df_rank['team'] == row['Away_team']]
    dates = away_team_rank_rows['date'].values
    away_team_rank_rows = away_team_rank_rows.sort_values(by='date',ascending=True)
    
    previous = False
    previous_rank_row = None
    for index_rank, row_rank in away_team_rank_rows.iterrows():
        date = row_rank['date']
        if date >= row['Date'] and previous:
            df.at[index, 'Away_rank'] = previous_rank_row['rank']
            break;
        elif date < row['Date']: 
            previous = True
            previous_rank_row = row_rank

# %%
df
# Out:
#           Date Score    Home_team    Away_team  Home_goals  Away_goals  \
# 0   2018-09-08   6-0  Switzerland      Iceland           6           0
# 1   2018-09-11   1-0      England  Switzerland           1           0
# 2   2018-10-12   2-1      Belgium  Switzerland           2           1
# 3   2018-10-15   1-2      Iceland  Switzerland           1           2
# 4   2018-11-14   0-1  Switzerland        Qatar           0           1
# ..         ...   ...          ...          ...         ...         ...
# 620 2020-11-12   2-1      Hungary      Iceland           2           1
# 621 2020-11-15   1-1      Hungary       Serbia           1           1
# 622 2020-11-18   2-0      Hungary       Turkey           2           0
# 623 2021-03-28   0-3   San Marino      Hungary           0           3
# 624 2021-03-31   1-4      Andorra      Hungary           1           4
#
#      Home_rank  Away_rank
# 0            8         32
# 1            6          8
# 2            1          8
# 3           36          8
# 4            8         96
# ..         ...        ...
# 620         47         39
# 621         47         30
# 622         47         33
# 623        210         40
# 624        151         40
#
# [625 rows x 8 columns]

# %%
df.mean()
# Out:
# <ipython-input-15-c61f0c8f89b5>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.mean()
# Home_goals     1.8080
# Away_goals     1.2032
# Home_rank     36.9440
# Away_rank     40.0928
# dtype: float64

# %%
skellam.pmf(0.0,  df.mean()[0],  df.mean()[1])
# Out:
# <ipython-input-16-84506962494c>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   skellam.pmf(0.0,  df.mean()[0],  df.mean()[1])
# 0.23074803045586798

# %%
skellam.pmf(1,  df.mean()[0],  df.mean()[1])
# Out:
# <ipython-input-17-aed2aa8c9ef6>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   skellam.pmf(1,  df.mean()[0],  df.mean()[1])
# 0.22804210068609898

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
goal_model_data = pd.concat([df[['Home_team','Away_team','Home_goals']].assign(home=1).rename(
            columns={'Home_team':'team', 'Away_team':'opponent','Home_goals':'goals'}),
           df[['Away_team','Home_team','Away_goals']].assign(home=0).rename(
            columns={'Away_team':'team', 'Home_team':'opponent','Away_goals':'goals'})])

# %%
goal_model_data = pd.concat([df[['Home_team','Home_rank','Away_team','Away_rank','Home_goals']].assign(home=1).rename(
            columns={'Home_team':'team', 'Home_rank':'home_rank', 'Away_team':'opponent', 'Away_rank':'opponent_rank','Home_goals':'goals'}),
           df[['Away_team','Away_rank','Home_team','Home_rank','Away_goals']].assign(home=0).rename(
            columns={'Away_team':'team', 'Away_rank':'home_rank', 'Home_team':'opponent', 'Home_rank':'opponent_rank','Away_goals':'goals'})])

# %%
goal_model_data
# Out:
#             team  home_rank     opponent  opponent_rank  goals  home
# 0    Switzerland          8      Iceland             32      6     1
# 1        England          6  Switzerland              8      1     1
# 2        Belgium          1  Switzerland              8      2     1
# 3        Iceland         36  Switzerland              8      1     1
# 4    Switzerland          8        Qatar             96      0     1
# ..           ...        ...          ...            ...    ...   ...
# 620      Iceland         39      Hungary             47      1     0
# 621       Serbia         30      Hungary             47      1     0
# 622       Turkey         33      Hungary             47      0     0
# 623      Hungary         40   San Marino            210      3     0
# 624      Hungary         40      Andorra            151      4     0
#
# [1250 rows x 6 columns]

# %%
poisson_model = smf.glm(formula="goals ~ home + team + opponent", data=goal_model_data, 
                        family=sm.families.Poisson()).fit()
poisson_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  goals   No. Observations:                 1250
# Model:                            GLM   Df Residuals:                     1108
# Model Family:                 Poisson   Df Model:                          141
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -1691.6
# Date:                Wed, 02 Jun 2021   Deviance:                       1152.8
# Time:                        16:54:12   Pearson chi2:                 1.04e+03
# No. Iterations:                    23
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -1.1982      0.754     -1.588      0.112      -2.677       0.280
# team[T.Andorra]                       -0.3430      1.227     -0.280      0.780      -2.748       2.062
# team[T.Argentina]                      2.2334      1.013      2.204      0.028       0.247       4.220
# team[T.Armenia]                        1.4054      0.805      1.747      0.081      -0.172       2.983
# team[T.Austria]                        1.6805      0.728      2.310      0.021       0.254       3.107
# team[T.Azerbaijan]                     0.9265      0.821      1.128      0.259      -0.683       2.536
# team[T.Bahrain]                        1.5526      1.235      1.258      0.209      -0.867       3.972
# team[T.Belarus]                       -0.1452      1.230     -0.118      0.906      -2.555       2.265
# team[T.Belgium]                        2.3706      0.717      3.308      0.001       0.966       3.775
# team[T.Bolivia]                      -21.3780    6.9e+04     -0.000      1.000   -1.35e+05    1.35e+05
# team[T.Bosnia and Herzegovina]         1.3825      0.775      1.784      0.074      -0.136       2.901
# team[T.Brazil]                         2.6893      0.927      2.900      0.004       0.872       4.507
# team[T.Bulgaria]                       0.6971      0.841      0.829      0.407      -0.951       2.345
# team[T.Croatia]                        2.0371      0.721      2.825      0.005       0.624       3.451
# team[T.Cyprus]                         0.5076      0.869      0.584      0.559      -1.196       2.211
# team[T.Czech Republic]                 1.5038      0.725      2.075      0.038       0.084       2.924
# team[T.Denmark]                        2.0174      0.721      2.797      0.005       0.604       3.431
# team[T.England]                        2.2606      0.719      3.142      0.002       0.851       3.671
# team[T.Estonia]                        1.1160      0.775      1.440      0.150      -0.403       2.635
# team[T.Faroe Islands]                  0.4331      1.004      0.431      0.666      -1.535       2.401
# team[T.Finland]                        1.4365      0.728      1.972      0.049       0.009       2.864
# team[T.France]                         2.0035      0.721      2.778      0.005       0.590       3.417
# team[T.Georgia]                        0.7547      0.845      0.894      0.372      -0.901       2.410
# team[T.Germany]                        2.0359      0.722      2.822      0.005       0.622       3.450
# team[T.Gibraltar]                     -0.4774      1.230     -0.388      0.698      -2.889       1.934
# team[T.Greece]                         1.2637      0.798      1.583      0.113      -0.301       2.828
# team[T.Hungary]                        1.4997      0.725      2.069      0.039       0.079       2.920
# team[T.Iceland]                        1.1638      0.772      1.508      0.132      -0.349       2.677
# team[T.Israel]                         1.5294      0.742      2.061      0.039       0.075       2.984
# team[T.Italy]                          2.0111      0.723      2.782      0.005       0.594       3.428
# team[T.Ivory Coast]                    2.0666      1.240      1.666      0.096      -0.365       4.498
# team[T.Jordan]                         1.4526      1.008      1.442      0.149      -0.522       3.428
# team[T.Kazakhstan]                     0.9294      0.840      1.107      0.268      -0.716       2.575
# team[T.Kosovo]                         1.6550      0.780      2.121      0.034       0.126       3.184
# team[T.Latvia]                         1.0112      0.844      1.198      0.231      -0.644       2.666
# team[T.Liechtenstein]                 -0.4626      1.233     -0.375      0.708      -2.880       1.954
# team[T.Lithuania]                     -0.0655      1.230     -0.053      0.958      -2.476       2.345
# team[T.Luxembourg]                     0.3824      1.007      0.380      0.704      -1.591       2.355
# team[T.Malta]                          0.7041      0.918      0.767      0.443      -1.096       2.504
# team[T.Mexico]                         1.1665      1.232      0.947      0.344      -1.247       3.580
# team[T.Moldova]                        0.2162      1.002      0.216      0.829      -1.748       2.181
# team[T.Montenegro]                     0.9439      0.919      1.027      0.304      -0.857       2.745
# team[T.Netherlands]                    2.1261      0.722      2.946      0.003       0.712       3.540
# team[T.Nigeria]                        2.2458      1.012      2.219      0.026       0.262       4.229
# team[T.North Macedonia]                1.3904      0.730      1.906      0.057      -0.039       2.820
# team[T.Northern Ireland]               1.1888      0.799      1.488      0.137      -0.377       2.754
# team[T.Norway]                         1.6963      0.797      2.128      0.033       0.134       3.259
# team[T.Paraguay]                       1.4504      1.235      1.174      0.240      -0.971       3.872
# team[T.Peru]                           1.7311      1.009      1.715      0.086      -0.247       3.709
# team[T.Poland]                         1.8397      0.725      2.536      0.011       0.418       3.261
# team[T.Portugal]                       2.1323      0.721      2.959      0.003       0.720       3.545
# team[T.Qatar]                          1.6344      1.235      1.324      0.186      -0.786       4.054
# team[T.Republic of Ireland]            0.8508      0.807      1.054      0.292      -0.731       2.433
# team[T.Romania]                        1.4607      0.798      1.831      0.067      -0.103       3.025
# team[T.Russia]                         1.9733      0.719      2.746      0.006       0.565       3.382
# team[T.San Marino]                   -21.7215    2.2e+04     -0.001      0.999   -4.31e+04    4.31e+04
# team[T.Scotland]                       1.5759      0.726      2.171      0.030       0.153       2.999
# team[T.Serbia]                         1.9039      0.744      2.561      0.010       0.447       3.361
# team[T.Slovakia]                       1.6208      0.723      2.241      0.025       0.204       3.038
# team[T.Slovenia]                       1.3668      0.798      1.712      0.087      -0.198       2.932
# team[T.Spain]                          2.2568      0.720      3.136      0.002       0.846       3.667
# team[T.Sweden]                         1.5628      0.723      2.162      0.031       0.146       2.980
# team[T.Switzerland]                    2.0979      0.722      2.907      0.004       0.683       3.512
# team[T.Trinidad and Tobago]          -21.5212    6.9e+04     -0.000      1.000   -1.35e+05    1.35e+05
# team[T.Tunisia]                        2.1480      1.011      2.124      0.034       0.166       4.130
# team[T.Turkey]                         1.6630      0.724      2.298      0.022       0.244       3.082
# team[T.USA]                          -21.3066   3.37e+04     -0.001      0.999   -6.61e+04     6.6e+04
# team[T.Ukraine]                        1.5564      0.727      2.140      0.032       0.131       2.982
# team[T.Uruguay]                        1.7176      1.008      1.704      0.088      -0.258       3.693
# team[T.Uzbekistan]                   -21.6903    6.9e+04     -0.000      1.000   -1.35e+05    1.35e+05
# team[T.Wales]                          1.4577      0.730      1.996      0.046       0.027       2.889
# opponent[T.Andorra]                    0.3478      0.322      1.081      0.280      -0.283       0.978
# opponent[T.Argentina]                 -0.4970      0.761     -0.653      0.514      -1.989       0.995
# opponent[T.Armenia]                    0.3768      0.348      1.084      0.278      -0.304       1.058
# opponent[T.Austria]                   -0.3977      0.310     -1.282      0.200      -1.006       0.211
# opponent[T.Azerbaijan]                -0.0283      0.336     -0.084      0.933      -0.686       0.629
# opponent[T.Bahrain]                   -0.7107      1.043     -0.681      0.496      -2.755       1.334
# opponent[T.Belarus]                    0.1450      0.339      0.428      0.669      -0.520       0.810
# opponent[T.Belgium]                   -0.8684      0.306     -2.834      0.005      -1.469      -0.268
# opponent[T.Bolivia]                   -0.4646      0.754     -0.616      0.538      -1.943       1.013
# opponent[T.Bosnia and Herzegovina]    -0.5295      0.330     -1.605      0.109      -1.176       0.117
# opponent[T.Brazil]                    -0.6581      1.042     -0.632      0.527      -2.700       1.383
# opponent[T.Bulgaria]                   0.1411      0.321      0.440      0.660      -0.487       0.770
# opponent[T.Croatia]                   -0.2567      0.277     -0.927      0.354      -0.799       0.286
# opponent[T.Cyprus]                    -0.0819      0.335     -0.244      0.807      -0.739       0.575
# opponent[T.Czech Republic]            -0.3925      0.286     -1.371      0.170      -0.954       0.169
# opponent[T.Denmark]                   -0.8786      0.315     -2.791      0.005      -1.496      -0.262
# opponent[T.England]                   -0.6688      0.296     -2.260      0.024      -1.249      -0.089
# opponent[T.Estonia]                    0.3750      0.297      1.261      0.207      -0.208       0.958
# opponent[T.Faroe Islands]              0.3634      0.324      1.123      0.262      -0.271       0.998
# opponent[T.Finland]                   -0.2921      0.290     -1.006      0.314      -0.861       0.277
# opponent[T.France]                    -0.7078      0.306     -2.313      0.021      -1.308      -0.108
# opponent[T.Georgia]                   -0.3981      0.359     -1.108      0.268      -1.102       0.306
# opponent[T.Germany]                   -0.3421      0.288     -1.188      0.235      -0.907       0.222
# opponent[T.Gibraltar]                  0.7270      0.311      2.336      0.020       0.117       1.337
# opponent[T.Greece]                    -0.3867      0.359     -1.076      0.282      -1.091       0.318
# opponent[T.Hungary]                   -0.3610      0.295     -1.224      0.221      -0.939       0.217
# opponent[T.Iceland]                   -0.1678      0.291     -0.577      0.564      -0.737       0.402
# opponent[T.Israel]                     0.0215      0.309      0.070      0.944      -0.584       0.627
# opponent[T.Italy]                     -1.6327      0.399     -4.095      0.000      -2.414      -0.851
# opponent[T.Ivory Coast]               -1.5249      1.036     -1.471      0.141      -3.556       0.507
# opponent[T.Jordan]                     0.2480      0.465      0.534      0.594      -0.663       1.159
# opponent[T.Kazakhstan]                -0.2667      0.356     -0.750      0.453      -0.964       0.430
# opponent[T.Kosovo]                     0.0782      0.329      0.238      0.812      -0.567       0.723
# opponent[T.Latvia]                     0.1925      0.339      0.568      0.570      -0.472       0.856
# opponent[T.Liechtenstein]              0.7159      0.331      2.160      0.031       0.066       1.366
# opponent[T.Lithuania]                  0.2111      0.347      0.608      0.543      -0.469       0.892
# opponent[T.Luxembourg]                 0.0558      0.352      0.158      0.874      -0.635       0.747
# opponent[T.Malta]                      0.2819      0.329      0.856      0.392      -0.364       0.928
# opponent[T.Mexico]                    -1.6941      1.036     -1.636      0.102      -3.724       0.336
# opponent[T.Moldova]                    0.4061      0.310      1.311      0.190      -0.201       1.013
# opponent[T.Montenegro]                 0.4892      0.346      1.414      0.157      -0.189       1.167
# opponent[T.Netherlands]               -0.7688      0.297     -2.586      0.010      -1.352      -0.186
# opponent[T.Nigeria]                   -0.0175      0.767     -0.023      0.982      -1.520       1.485
# opponent[T.North Macedonia]           -0.1380      0.310     -0.445      0.656      -0.746       0.469
# opponent[T.Northern Ireland]          -0.1317      0.334     -0.395      0.693      -0.786       0.522
# opponent[T.Norway]                    -0.2068      0.380     -0.544      0.586      -0.952       0.538
# opponent[T.Paraguay]                  -0.7751      1.040     -0.745      0.456      -2.814       1.264
# opponent[T.Peru]                      -0.5431      0.568     -0.956      0.339      -1.657       0.570
# opponent[T.Poland]                    -0.7420      0.303     -2.450      0.014      -1.336      -0.148
# opponent[T.Portugal]                  -0.9744      0.314     -3.107      0.002      -1.589      -0.360
# opponent[T.Qatar]                    -24.5361    6.9e+04     -0.000      1.000   -1.35e+05    1.35e+05
# opponent[T.Republic of Ireland]       -0.5191      0.336     -1.544      0.122      -1.178       0.140
# opponent[T.Romania]                   -0.0526      0.356     -0.148      0.882      -0.750       0.644
# opponent[T.Russia]                    -0.2658      0.284     -0.937      0.349      -0.822       0.290
# opponent[T.San Marino]                 0.6815      0.290      2.353      0.019       0.114       1.249
# opponent[T.Scotland]                  -0.0670      0.286     -0.234      0.815      -0.627       0.493
# opponent[T.Serbia]                    -0.0822      0.318     -0.258      0.796      -0.706       0.542
# opponent[T.Slovakia]                  -0.2522      0.288     -0.877      0.380      -0.816       0.311
# opponent[T.Slovenia]                  -0.5225      0.409     -1.276      0.202      -1.325       0.280
# opponent[T.Spain]                     -0.9999      0.315     -3.178      0.001      -1.617      -0.383
# opponent[T.Sweden]                    -0.5594      0.284     -1.973      0.048      -1.115      -0.004
# opponent[T.Switzerland]               -0.4362      0.285     -1.532      0.125      -0.994       0.122
# opponent[T.Trinidad and Tobago]       -0.6119      1.043     -0.587      0.557      -2.655       1.431
# opponent[T.Tunisia]                   -1.1914      1.039     -1.146      0.252      -3.229       0.846
# opponent[T.Turkey]                    -0.3955      0.294     -1.343      0.179      -0.973       0.182
# opponent[T.USA]                       -1.1525      0.562     -2.050      0.040      -2.254      -0.051
# opponent[T.Ukraine]                   -0.3544      0.282     -1.258      0.208      -0.907       0.198
# opponent[T.Uruguay]                   -0.9373      0.753     -1.245      0.213      -2.412       0.538
# opponent[T.Uzbekistan]                -0.1241      0.757     -0.164      0.870      -1.608       1.360
# opponent[T.Wales]                     -0.5646      0.299     -1.889      0.059      -1.150       0.021
# home                                   0.3525      0.049      7.248      0.000       0.257       0.448
# ======================================================================================================
# """

# %%
poisson_model = smf.glm(formula="goals ~ home + home_rank + team + opponent + opponent_rank", data=goal_model_data, 
                        family=sm.families.Poisson()).fit()
poisson_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  goals   No. Observations:                 1250
# Model:                            GLM   Df Residuals:                     1106
# Model Family:                 Poisson   Df Model:                          143
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -1687.8
# Date:                Wed, 02 Jun 2021   Deviance:                       1145.3
# Time:                        16:54:14   Pearson chi2:                 1.03e+03
# No. Iterations:                    23
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -1.4802      0.792     -1.869      0.062      -3.032       0.072
# team[T.Andorra]                       -1.0161      1.266     -0.803      0.422      -3.498       1.465
# team[T.Argentina]                      2.6634      1.033      2.577      0.010       0.638       4.689
# team[T.Armenia]                        1.0495      0.819      1.281      0.200      -0.556       2.655
# team[T.Austria]                        1.9663      0.741      2.653      0.008       0.514       3.419
# team[T.Azerbaijan]                     0.5353      0.841      0.636      0.525      -1.114       2.184
# team[T.Bahrain]                        1.2326      1.243      0.992      0.321      -1.204       3.669
# team[T.Belarus]                       -0.3255      1.232     -0.264      0.792      -2.741       2.090
# team[T.Belgium]                        2.8873      0.754      3.828      0.000       1.409       4.366
# team[T.Bolivia]                      -21.3897    6.9e+04     -0.000      1.000   -1.35e+05    1.35e+05
# team[T.Bosnia and Herzegovina]         1.5072      0.777      1.939      0.053      -0.016       3.031
# team[T.Brazil]                         3.1846      0.956      3.331      0.001       1.311       5.058
# team[T.Bulgaria]                       0.6984      0.841      0.830      0.406      -0.950       2.347
# team[T.Croatia]                        2.4891      0.751      3.312      0.001       1.016       3.962
# team[T.Cyprus]                         0.2619      0.878      0.298      0.765      -1.459       1.982
# team[T.Czech Republic]                 1.6494      0.728      2.266      0.023       0.223       3.076
# team[T.Denmark]                        2.4102      0.745      3.236      0.001       0.951       3.870
# team[T.England]                        2.7383      0.753      3.638      0.000       1.263       4.213
# team[T.Estonia]                        0.7930      0.790      1.004      0.316      -0.756       2.342
# team[T.Faroe Islands]                  0.0582      1.020      0.057      0.954      -1.941       2.057
# team[T.Finland]                        1.4601      0.729      2.003      0.045       0.032       2.889
# team[T.France]                         2.4870      0.757      3.286      0.001       1.003       3.971
# team[T.Georgia]                        0.5486      0.851      0.645      0.519      -1.120       2.217
# team[T.Germany]                        2.4288      0.745      3.260      0.001       0.969       3.889
# team[T.Gibraltar]                     -1.6454      1.337     -1.231      0.218      -4.266       0.975
# team[T.Greece]                         1.3685      0.800      1.711      0.087      -0.199       2.936
# team[T.Hungary]                        1.6001      0.726      2.203      0.028       0.177       3.024
# team[T.Iceland]                        1.3489      0.777      1.737      0.082      -0.173       2.871
# team[T.Israel]                         1.3141      0.750      1.753      0.080      -0.155       2.783
# team[T.Italy]                          2.3225      0.746      3.115      0.002       0.861       3.784
# team[T.Ivory Coast]                    2.5786      1.263      2.041      0.041       0.103       5.055
# team[T.Jordan]                         1.1100      1.020      1.088      0.277      -0.890       3.110
# team[T.Kazakhstan]                     0.4800      0.867      0.554      0.580      -1.219       2.179
# team[T.Kosovo]                         1.1984      0.810      1.479      0.139      -0.389       2.786
# team[T.Latvia]                         0.3802      0.893      0.426      0.670      -1.369       2.130
# team[T.Liechtenstein]                 -1.5078      1.318     -1.144      0.253      -4.092       1.076
# team[T.Lithuania]                     -0.6347      1.258     -0.504      0.614      -3.101       1.832
# team[T.Luxembourg]                     0.1256      1.014      0.124      0.901      -1.861       2.113
# team[T.Malta]                         -0.2525      1.023     -0.247      0.805      -2.257       1.752
# team[T.Mexico]                         1.5756      1.247      1.263      0.206      -0.869       4.020
# team[T.Moldova]                       -0.7053      1.092     -0.646      0.518      -2.845       1.434
# team[T.Montenegro]                     1.0087      0.919      1.097      0.273      -0.793       2.811
# team[T.Netherlands]                    2.5015      0.744      3.363      0.001       1.044       3.960
# team[T.Nigeria]                        2.4725      1.018      2.429      0.015       0.477       4.468
# team[T.North Macedonia]                1.5391      0.732      2.102      0.036       0.104       2.974
# team[T.Northern Ireland]               1.4008      0.805      1.740      0.082      -0.177       2.979
# team[T.Norway]                         1.8114      0.799      2.266      0.023       0.245       3.378
# team[T.Paraguay]                       1.6302      1.238      1.316      0.188      -0.797       4.058
# team[T.Peru]                           2.0722      1.022      2.027      0.043       0.069       4.076
# team[T.Poland]                         2.1761      0.743      2.927      0.003       0.719       3.633
# team[T.Portugal]                       2.5867      0.752      3.441      0.001       1.113       4.060
# team[T.Qatar]                          1.3411      1.242      1.080      0.280      -1.093       3.775
# team[T.Republic of Ireland]            1.0810      0.814      1.328      0.184      -0.515       2.677
# team[T.Romania]                        1.6991      0.805      2.110      0.035       0.121       3.278
# team[T.Russia]                         2.1576      0.723      2.984      0.003       0.740       3.575
# team[T.San Marino]                   -22.8405   2.11e+04     -0.001      0.999   -4.14e+04    4.14e+04
# team[T.Scotland]                       1.7270      0.729      2.370      0.018       0.299       3.155
# team[T.Serbia]                         2.1514      0.753      2.857      0.004       0.675       3.628
# team[T.Slovakia]                       1.8741      0.733      2.558      0.011       0.438       3.310
# team[T.Slovenia]                       1.3418      0.799      1.680      0.093      -0.223       2.907
# team[T.Spain]                          2.6969      0.749      3.598      0.000       1.228       4.166
# team[T.Sweden]                         1.9311      0.745      2.593      0.010       0.471       3.391
# team[T.Switzerland]                    2.4899      0.745      3.340      0.001       1.029       3.951
# team[T.Trinidad and Tobago]          -21.7898    6.9e+04     -0.000      1.000   -1.35e+05    1.35e+05
# team[T.Tunisia]                        2.4238      1.020      2.377      0.017       0.425       4.423
# team[T.Turkey]                         1.8692      0.731      2.558      0.011       0.437       3.301
# team[T.USA]                          -20.9439   3.38e+04     -0.001      1.000   -6.62e+04    6.62e+04
# team[T.Ukraine]                        1.8468      0.740      2.495      0.013       0.396       3.298
# team[T.Uruguay]                        2.1712      1.031      2.107      0.035       0.151       4.191
# team[T.Uzbekistan]                   -21.8721    6.9e+04     -0.000      1.000   -1.35e+05    1.35e+05
# team[T.Wales]                          1.7878      0.747      2.394      0.017       0.324       3.251
# opponent[T.Andorra]                    0.6313      0.349      1.809      0.070      -0.053       1.315
# opponent[T.Argentina]                 -0.7030      0.766     -0.917      0.359      -2.205       0.799
# opponent[T.Armenia]                    0.5508      0.358      1.539      0.124      -0.151       1.252
# opponent[T.Austria]                   -0.5122      0.316     -1.622      0.105      -1.131       0.107
# opponent[T.Azerbaijan]                 0.1347      0.345      0.391      0.696      -0.541       0.811
# opponent[T.Bahrain]                   -0.5691      1.045     -0.545      0.586      -2.617       1.479
# opponent[T.Belarus]                    0.2108      0.341      0.618      0.536      -0.458       0.879
# opponent[T.Belgium]                   -1.0867      0.324     -3.355      0.001      -1.721      -0.452
# opponent[T.Bolivia]                   -0.4609      0.754     -0.611      0.541      -1.939       1.017
# opponent[T.Bosnia and Herzegovina]    -0.5711      0.330     -1.730      0.084      -1.218       0.076
# opponent[T.Brazil]                    -0.8718      1.046     -0.833      0.405      -2.923       1.179
# opponent[T.Bulgaria]                   0.1378      0.321      0.430      0.668      -0.491       0.766
# opponent[T.Croatia]                   -0.4635      0.292     -1.586      0.113      -1.036       0.109
# opponent[T.Cyprus]                    -0.0107      0.338     -0.032      0.975      -0.673       0.652
# opponent[T.Czech Republic]            -0.4768      0.288     -1.653      0.098      -1.042       0.088
# opponent[T.Denmark]                   -1.0559      0.326     -3.239      0.001      -1.695      -0.417
# opponent[T.England]                   -0.8735      0.311     -2.804      0.005      -1.484      -0.263
# opponent[T.Estonia]                    0.4997      0.307      1.628      0.103      -0.102       1.101
# opponent[T.Faroe Islands]              0.5046      0.333      1.517      0.129      -0.147       1.156
# opponent[T.Finland]                   -0.3109      0.290     -1.071      0.284      -0.880       0.258
# opponent[T.France]                    -0.9257      0.322     -2.879      0.004      -1.556      -0.296
# opponent[T.Georgia]                   -0.3309      0.363     -0.911      0.362      -1.043       0.381
# opponent[T.Germany]                   -0.5165      0.299     -1.730      0.084      -1.102       0.069
# opponent[T.Gibraltar]                  1.2524      0.389      3.224      0.001       0.491       2.014
# opponent[T.Greece]                    -0.4193      0.359     -1.166      0.243      -1.124       0.285
# opponent[T.Hungary]                   -0.3963      0.296     -1.341      0.180      -0.976       0.183
# opponent[T.Iceland]                   -0.2551      0.294     -0.869      0.385      -0.831       0.321
# opponent[T.Israel]                     0.0807      0.312      0.258      0.796      -0.532       0.693
# opponent[T.Italy]                     -1.7943      0.405     -4.429      0.000      -2.588      -1.000
# opponent[T.Ivory Coast]               -1.7697      1.043     -1.697      0.090      -3.814       0.274
# opponent[T.Jordan]                     0.3997      0.470      0.850      0.395      -0.522       1.321
# opponent[T.Kazakhstan]                -0.1095      0.365     -0.300      0.764      -0.826       0.606
# opponent[T.Kosovo]                     0.2553      0.342      0.746      0.456      -0.415       0.926
# opponent[T.Latvia]                     0.4639      0.363      1.279      0.201      -0.247       1.175
# opponent[T.Liechtenstein]              1.1964      0.401      2.984      0.003       0.411       1.982
# opponent[T.Lithuania]                  0.4579      0.368      1.245      0.213      -0.263       1.179
# opponent[T.Luxembourg]                 0.1591      0.356      0.446      0.655      -0.539       0.858
# opponent[T.Malta]                      0.6747      0.383      1.762      0.078      -0.076       1.425
# opponent[T.Mexico]                    -1.8555      1.039     -1.786      0.074      -3.892       0.181
# opponent[T.Moldova]                    0.8092      0.366      2.213      0.027       0.092       1.526
# opponent[T.Montenegro]                 0.4492      0.347      1.296      0.195      -0.230       1.128
# opponent[T.Netherlands]               -0.9284      0.306     -3.030      0.002      -1.529      -0.328
# opponent[T.Nigeria]                   -0.1148      0.768     -0.149      0.881      -1.620       1.391
# opponent[T.North Macedonia]           -0.1981      0.311     -0.636      0.525      -0.808       0.412
# opponent[T.Northern Ireland]          -0.2140      0.336     -0.638      0.524      -0.872       0.444
# opponent[T.Norway]                    -0.2609      0.381     -0.685      0.493      -1.007       0.485
# opponent[T.Paraguay]                  -0.8437      1.041     -0.810      0.418      -2.884       1.197
# opponent[T.Peru]                      -0.7055      0.572     -1.233      0.218      -1.827       0.416
# opponent[T.Poland]                    -0.8744      0.309     -2.833      0.005      -1.479      -0.270
# opponent[T.Portugal]                  -1.1689      0.326     -3.587      0.000      -1.807      -0.530
# opponent[T.Qatar]                    -24.3749    6.9e+04     -0.000      1.000   -1.35e+05    1.35e+05
# opponent[T.Republic of Ireland]       -0.6147      0.339     -1.811      0.070      -1.280       0.051
# opponent[T.Romania]                   -0.1772      0.359     -0.494      0.622      -0.881       0.526
# opponent[T.Russia]                    -0.3538      0.286     -1.237      0.216      -0.914       0.207
# opponent[T.San Marino]                 1.0953      0.342      3.199      0.001       0.424       1.766
# opponent[T.Scotland]                  -0.1522      0.288     -0.528      0.597      -0.717       0.412
# opponent[T.Serbia]                    -0.1881      0.323     -0.583      0.560      -0.820       0.444
# opponent[T.Slovakia]                  -0.3779      0.293     -1.291      0.197      -0.952       0.196
# opponent[T.Slovenia]                  -0.5447      0.410     -1.329      0.184      -1.348       0.258
# opponent[T.Spain]                     -1.1925      0.327     -3.642      0.000      -1.834      -0.551
# opponent[T.Sweden]                    -0.7132      0.293     -2.431      0.015      -1.288      -0.138
# opponent[T.Switzerland]               -0.6232      0.298     -2.092      0.036      -1.207      -0.039
# opponent[T.Trinidad and Tobago]       -0.4899      1.044     -0.469      0.639      -2.536       1.556
# opponent[T.Tunisia]                   -1.3030      1.041     -1.252      0.211      -3.343       0.737
# opponent[T.Turkey]                    -0.4951      0.298     -1.660      0.097      -1.080       0.089
# opponent[T.USA]                       -1.2776      0.566     -2.258      0.024      -2.386      -0.169
# opponent[T.Ukraine]                   -0.4835      0.288     -1.680      0.093      -1.047       0.080
# opponent[T.Uruguay]                   -1.1385      0.758     -1.502      0.133      -2.625       0.348
# opponent[T.Uzbekistan]                -0.0707      0.758     -0.093      0.926      -1.557       1.415
# opponent[T.Wales]                     -0.7132      0.307     -2.321      0.020      -1.315      -0.111
# home                                   0.3508      0.049      7.210      0.000       0.255       0.446
# home_rank                              0.0082      0.004      2.126      0.033       0.001       0.016
# opponent_rank                         -0.0035      0.002     -2.091      0.037      -0.007      -0.000
# ======================================================================================================
# """

# %%
#poisson_model = smf.glm(formula="goals ~ team + opponent", data=goal_model_data, family=sm.families.Poisson()).fit()
#poisson_model.summary()

# %%
#27 May 2021
fifa_ranking_dict = {
    'Turkey': 29, 
    'Italy': 7,
    'Wales': 17,
    'Switzerland': 13,
    'Denmark': 10,
    'Finland': 54,
    'Belgium': 1,
    'Russia': 38,
    'England': 4,
    'Croatia': 14,
    'Austria': 23,
    'North Macedonia': 62,
    'Netherlands': 16,
    'Ukraine': 24,
    'Scotland': 44,
    'Czech Republic': 40,
    'Poland': 21,
    'Slovakia': 36,
    'Spain': 6,
    'Sweden': 18,
    'Hungary': 37,
    'Portugal': 5,
    'France': 2,
    'Germany': 12
}

# %%
def simulate_match(foot_model, homeTeam, awayTeam, max_goals=10):
    home_goals_avg = foot_model.predict(pd.DataFrame(data={'team': homeTeam,
                                                           'home_rank': fifa_ranking_dict.get(homeTeam),
                                                           'opponent': awayTeam,
                                                           'opponent_rank': fifa_ranking_dict.get(awayTeam),
                                                           'home':1},
                                                      index=[1])).values[0]
    away_goals_avg = foot_model.predict(pd.DataFrame(data={'team': awayTeam, 
                                                           'home_rank': fifa_ranking_dict.get(awayTeam),
                                                           'opponent': homeTeam,
                                                           'opponent_rank': fifa_ranking_dict.get(homeTeam),
                                                           'home':0},
                                                      index=[1])).values[0]
    team_pred = [[poisson.pmf(i, team_avg) for i in range(0, max_goals+1)] for team_avg in [home_goals_avg, away_goals_avg]]
    return(np.outer(np.array(team_pred[0]), np.array(team_pred[1])))

# %%
simulate_match(poisson_model, 'Germany', 'Belgium', max_goals=4)
# Out:
# array([[0.02431612, 0.05728652, 0.06748088, 0.0529929 , 0.0312116 ],
#        [0.03308714, 0.07795025, 0.09182179, 0.07210789, 0.04246988],
#        [0.02251097, 0.05303378, 0.06247134, 0.0490589 , 0.02889456],
#        [0.01021029, 0.0240545 , 0.02833509, 0.02225162, 0.01310569],
#        [0.00347331, 0.00818279, 0.00963895, 0.00756949, 0.00445826]])

# %%
sun = simulate_match(poisson_model, 'Germany', 'Belgium', max_goals=10)

# %%
np.sum(np.tril(sun, -1))
# Out:
# 0.21187331284596525

# %%
np.sum(np.diag(sun))
# Out:
# 0.19207365969797288

# %%
np.sum(np.tril(sun, 1))
# Out:
# 0.6175631519616525

# %%
def predict_game_result(home_team, away_team):
    home_goals = poisson_model.predict(pd.DataFrame(data={
        'team': home_team, 'home_rank': fifa_ranking_dict.get(home_team),'opponent': away_team, 'opponent_rank': fifa_ranking_dict.get(away_team), 'home': 1
    },index=[1]))
    away_goals = poisson_model.predict(pd.DataFrame(data={
        'team': away_team, 'home_rank': fifa_ranking_dict.get(away_team), 'opponent': home_team, 'opponent_rank': fifa_ranking_dict.get(home_team), 'home': 0
    },index=[1]))
    print(str(home_team) + " " + str(int(round(home_goals))) + " - " + str(int(round(away_goals))) + " " + str(away_team))

# %% [markdown]
# EM-KISAT 2021 PREDICTIONS

# %%
predict_game_result('Turkey', 'Italy')
# Out:
# Turkey 0 - 1 Italy

# %%
predict_game_result('Wales', 'Switzerland')
# Out:
# Wales 1 - 1 Switzerland

# %%
predict_game_result('Denmark', 'Finland')
# Out:
# Denmark 2 - 1 Finland

# %%
predict_game_result('Belgium', 'Russia')
# Out:
# Belgium 4 - 1 Russia

# %%
predict_game_result('England', 'Croatia')
# Out:
# England 3 - 1 Croatia

# %%
predict_game_result('Austria', 'North Macedonia')
# Out:
# Austria 2 - 1 North Macedonia

# %%
predict_game_result('Netherlands', 'Ukraine')
# Out:
# Netherlands 3 - 1 Ukraine

# %%
predict_game_result('Scotland', 'Czech Republic')
# Out:
# Scotland 1 - 1 Czech Republic

# %%
predict_game_result('Poland', 'Slovakia')
# Out:
# Poland 2 - 1 Slovakia

# %%
predict_game_result('Spain', 'Sweden')
# Out:
# Spain 2 - 1 Sweden

# %%
predict_game_result('Hungary', 'Portugal')
# Out:
# Hungary 1 - 2 Portugal

# %%
predict_game_result('France', 'Germany')
# Out:
# France 2 - 1 Germany

# %%
predict_game_result('Finland', 'Russia')
# Out:
# Finland 1 - 2 Russia

# %%
predict_game_result('Turkey', 'Wales')
# Out:
# Turkey 1 - 1 Wales

# %%
predict_game_result('Italy', 'Switzerland')
# Out:
# Italy 2 - 0 Switzerland

# %%
predict_game_result('Ukraine', 'North Macedonia')
# Out:
# Ukraine 2 - 1 North Macedonia

# %%
predict_game_result('Denmark', 'Belgium')
# Out:
# Denmark 1 - 1 Belgium

# %%
predict_game_result('Netherlands', 'Austria')
# Out:
# Netherlands 2 - 1 Austria

# %%
predict_game_result('Sweden', 'Slovakia')
# Out:
# Sweden 2 - 1 Slovakia

# %%
predict_game_result('Croatia', 'Czech Republic')
# Out:
# Croatia 2 - 1 Czech Republic

# %%
predict_game_result('England', 'Scotland')
# Out:
# England 4 - 1 Scotland

# %%
predict_game_result('Hungary', 'France')
# Out:
# Hungary 1 - 2 France

# %%
predict_game_result('Portugal', 'Germany')
# Out:
# Portugal 3 - 1 Germany

# %%
predict_game_result('Spain', 'Poland')
# Out:
# Spain 2 - 1 Poland

# %%
predict_game_result('Italy', 'Wales')
# Out:
# Italy 2 - 0 Wales

# %%
predict_game_result('Switzerland', 'Turkey')
# Out:
# Switzerland 2 - 1 Turkey

# %%
predict_game_result('Ukraine', 'Austria')
# Out:
# Ukraine 1 - 1 Austria

# %%
predict_game_result('North Macedonia', 'Netherlands')
# Out:
# North Macedonia 1 - 2 Netherlands

# %%
predict_game_result('Finland', 'Belgium')
# Out:
# Finland 1 - 2 Belgium

# %%
predict_game_result('Russia', 'Denmark')
# Out:
# Russia 1 - 2 Denmark

# %%
predict_game_result('Czech Republic', 'England')
# Out:
# Czech Republic 1 - 2 England

# %%
predict_game_result('Croatia', 'Scotland')
# Out:
# Croatia 3 - 1 Scotland

# %%
predict_game_result('Sweden', 'Poland')
# Out:
# Sweden 1 - 1 Poland

# %%
predict_game_result('Slovakia', 'Spain')
# Out:
# Slovakia 1 - 2 Spain

# %%
predict_game_result('Germany', 'Hungary')
# Out:
# Germany 2 - 1 Hungary

# %%
predict_game_result('Portugal', 'France')
# Out:
# Portugal 2 - 1 France
